# %% [markdown]
# Distribution of comments per video

# %%
import csv
from collections import Counter
import matplotlib.pyplot as plt
comment_counts = []
#read csv file
with open('commented_over_0.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        comment_count = int(row['Comment Count'])
        #append list of comment count
        comment_counts.append(comment_count)
#print maximum comment count       
max_value = max(comment_counts)
print("Maximum value:", max_value)
#sort comment count
comment = sorted(comment_counts, reverse=True)
#plot semilogy
plt.semilogy(comment, 'b-', marker='o')
plt.ylabel("Comments count for per video")
plt.xlabel("rank")
# Out:
# Maximum value: 173900
# Text(0.5, 0, 'rank')

# %% [markdown]
# Distribution of number of videos of per channel

# %%
import csv

video_IDs = []
channel_IDs = []

with open('commented_over_0.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        video_id = row['Video ID']
        channel_id = row['Channel ID']
        video_IDs.append(video_id)
        channel_IDs.append(channel_id)

# Count the number of videos published by each channel
channel_counts = {}
for channel_id in set(channel_IDs):
    count = channel_IDs.count(channel_id)
    channel_counts[channel_id] = count

# Write the results to a new CSV file
with open('Statistic/video_channel.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Channel ID', 'Video Count'])
    for channel_id, count in channel_counts.items():
        writer.writerow([channel_id, count])

print('Video counts saved to video_counts_per_channel.csv')
# Out:
# Video counts saved to video_counts_per_channel.csv

# %%
import csv
from collections import Counter
import matplotlib.pyplot as plt
#read created csv file and pick the video count
video_count=[]
with open('Statistic/video_channel.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        video_counts = int(row['Video Count'])
        video_count.append(video_counts)
#list of video count and sort them 
videos = sorted(video_count, reverse=True)
max_value = max(video_count)
print("Maximum value:", max_value)
#plot loglog
plt.loglog(videos, 'g-', marker='o')
plt.ylabel("Number of videos of per channel")
plt.xlabel("rank")
plt.show()
# Out:
# Maximum value: 507

# %% [markdown]
# Distribution of view counts

# %%
import csv
from collections import Counter
import matplotlib.pyplot as plt

comment_counts1 = []
comment_counts2 = []
# read csv file for only commented csv file
with open('commented_over_0.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        comment_count = int(row['View Count'])
        comment_counts1.append(comment_count)
#read all videos
with open('all_video_en.csv', 'r', newline='') as file1:
    reader = csv.DictReader(file1)
    for row in reader:
        comment_count1 = int(row['View Count'])
        comment_counts2.append(comment_count1)
#sort view counts for both data
comment_counts1.sort(reverse=True)
comment_counts2.sort(reverse=True)

max_value = max(comment_counts2)
print("Maximum value:", max_value)
# Plotting
plt.semilogy(comment_counts2, 'r-', marker='o', label='all downloaded vidoes')
plt.semilogy(comment_counts1, 'b-', marker='o', label='only commented videos')


plt.ylabel("View Counts per Video")
plt.xlabel("Rank")
plt.legend()

plt.show()
# Out:
# Maximum value: 44537626

# %% [markdown]
# Distribution of user comments number for per video

# %%
import csv

video_comments = {}  # Dictionary to store video ID and comment counts for each user

with open('all_comments.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        video_ID = row['Video ID']
        user_ID = row['User ID']

        # Check if the video ID exists in the dictionary
        if video_ID in video_comments:
            # Check if the user ID exists for the video
            if user_ID in video_comments[video_ID]:
                # Increment the comment count for the user
                video_comments[video_ID][user_ID] += 1
            else:
                # Initialize the comment count for the user
                video_comments[video_ID][user_ID] = 1
        else:
            # Initialize the video ID and comment count for the user
            video_comments[video_ID] = {user_ID: 1}

# Store the comment counts in a separate CSV file
output_file = 'Statistic/comment_counts.csv'
fieldnames = ['Video ID', 'User ID', 'Comment Count']

with open(output_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    
    for video_ID, comments in video_comments.items():
        for user_ID, count in comments.items():
            writer.writerow({'Video ID': video_ID, 'User ID': user_ID, 'Comment Count': count})

# %%
comment=[]
#read the Comment count and append 
with open('Statistic/comment_counts.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        comment_count = int(row['Comment Count'])
        comment.append(comment_count)

# %%
import networkx as nx
import matplotlib.pyplot as plt

#sort comment count 
comm_sort = sorted(comment, reverse=True)
#plot semilogy
plt.semilogy(comm_sort, 'b-', marker='o')
plt.ylabel(" A user comments number for per video")
plt.xlabel("rank")
plt.show()

# %% [markdown]
# Distribution for comment count per user

# %%
import csv

comment_counts = {}

with open('all_comments.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        user_ID = row['User ID']

        if user_ID in comment_counts:
            comment_counts[user_ID] += 1
        else:
            comment_counts[user_ID] = 1

# Write the comment counts to a new CSV file
with open('users.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['User ID', 'Comment Count'])  # Write the header row

    for user_ID, count in comment_counts.items():
        writer.writerow([user_ID, count])

# %%
import csv
from collections import Counter
import matplotlib.pyplot as plt
comment_counts = []

with open('users.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        comment_count = int(row['Comment Count'])
        comment_counts.append(comment_count)
        
max_value = max(comment_counts)
print("Maximum value:", max_value)

comment = sorted(comment_counts, reverse=True)
# print "Degree sequence", degree_sequence
dmax = max(degree_sequence)

plt.loglog(comment, 'b-', marker='o')
plt.ylabel("Comment Count per User ")
plt.xlabel("rank")
# Out:
# Maximum value: 13551
# Text(0.5, 0, 'rank')

# %% [markdown]
# Duration of videos by year

# %%
import matplotlib.pyplot as plt
from datetime import datetime
import csv
#read the duration and publication date
duration_strings = []
publishedDate = []
with open('commented_over_0.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        duration_strings.append(row['duration'])
        publishedDate.append(row['Publication Date'])

#convert duration to munites
durations = []
for duration_string in duration_strings:
    try:
        duration = datetime.strptime(duration_string, '%H:%M:%S')
        total_minutes = duration.hour * 60 + duration.minute + duration.second / 60
        durations.append(total_minutes)
    except ValueError:
        print(f"Invalid duration format: {duration_string}")

# Parse the published date strings to datetime objects
published_dates = [datetime.strptime(date, '%Y-%m-%dT%H:%M:%SZ') for date in publishedDate]

# Extract years from published dates
years = [date.year for date in published_dates]

# Create a dictionary to store durations by year
durations_by_year = {}
for year, duration in zip(years, durations):
    if year in durations_by_year:
        durations_by_year[year].append(duration)
    else:
        durations_by_year[year] = [duration]

# Create a list of duration values for each year
duration_values = [durations_by_year[year] for year in sorted(durations_by_year.keys())]

# Create the boxplot
plt.boxplot(duration_values)
plt.yscale('log')
plt.xticks(range(1, len(durations_by_year) + 1), sorted(durations_by_year.keys()), rotation=45) # Rotate the x-axis label by 45 degrees
plt.xlabel('Year')  
plt.ylabel('Minutes')
plt.show()

# %%
#import networkx as nx
import matplotlib.pyplot as plt
import csv

# Create the bipartite graph
B = nx.Graph()
#read csv file
with open('test.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        video = row['Video ID']
        user = row['User ID']
        B.add_edge(video, user)
        
# here is two set, lesft-hand side will be video ID, righ-hand side will be user ID
video_nodes, user_nodes = nx.bipartite.sets(B)


import networkx as nx
import matplotlib.pyplot as plt
import csv

# Create the bipartite graph
B = nx.Graph()
#read csv file
with open('test.csv', 'r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        video = row['Video ID']
        user = row['User ID']
        B.add_edge(video, user)
        
# here is two set, lesft-hand side will be video ID, righ-hand side will be user ID
video_nodes, user_nodes = nx.bipartite.sets(B)

# %%
if not nx.is_connected(B):
    # If the graph is not connected, create a separate bipartite graph for each connected component
    subgraphs = [B.subgraph(c) for c in nx.connected_components(B)]
    for B in subgraphs:
        # Compute the positions of the nodes
        pos = nx.bipartite_layout(B, nodes=list(video_nodes))
        # Draw the bipartite graph
        nx.draw(B, pos=pos)
        plt.show()
else:
    # Compute the positions of the nodes
    pos = nx.bipartite_layout(B, nodes=list(video_nodes))
    # Draw the bipartite graph
    plt.figure(figsize=(20, 20))
    nx.draw_networkx(B, pos=pos, node_size=150, width=0.2, node_color='red')
    plt.show()
